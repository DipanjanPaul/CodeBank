# %%
import pandas as pd
import numpy as np

from pandas_profiling import ProfileReport
import plotly.express as px
import re

from itertools import groupby
from datetime import datetime
import math

#import re
#from nltk.stem import WordNetLemmatizer, PorterStemmer, SnowballStemmer

#from nltk.corpus import stopwords
#from nltk.tokenize import word_tokenize

import networkx as nx

from networkx.readwrite import json_graph

import seaborn as sns

import matplotlib.pyplot as plt

import zipfile

pd.options.display.max_columns = 100
pd.options.display.max_rows = 300
pd.options.display.max_colwidth = 50

# %%
df_spec = pd.read_excel("../data/external/Exhibit C_Leveled Bid - Specs_RFP.xlsx", 
                   sheet_name='Serenity Leveled Bid Request',
                   header=12)

df_spec.drop(['Unnamed: 0'], axis=1, inplace=True)
df_spec.fillna('DNA', inplace=True) ## DNA: Does Not Apply
df_spec.shape
# Out:
# (85, 26)

# %%
upd_ix = [(x,y) for (x,y) in enumerate(df_spec.Area) if y != 'DNA']
##upd_ix

# %%
for i in range(len(upd_ix) - 1):
    df_spec.Area.iloc[upd_ix[i][0]: upd_ix[i+1][0]] = upd_ix[i][1]

i = i+1
df_spec.Area.iloc[upd_ix[i][0]:] = upd_ix[i][1]

# %%
df_spec = df_spec[['Area', 'Cost center', 'Item', 'Category', 'SKU/Spec', 'Color/Notes',
       'Reference']]

ix = df_spec.iloc[:,1:].apply(lambda x: np.sum(x == 'DNA') != len(x), axis=1)
df_spec = df_spec.loc[ix==True,:]

df_spec.head(2)
# Out:
#       Area Cost center              Item  Category  \
# 0  Kitchen   3-05-5410          Cabinets  Material
# 1  Kitchen   3-05-5410  Cabinets Install     Labor
#
#                                             SKU/Spec  \
# 0  5pc all wood shaker style cabinet - door & dra...
# 1  Remove existing doors, prep+paint boxes, insta...
#
#                 Color/Notes Reference
# 0  White above / Gray below       DNA
# 1                       DNA       DNA

# %%
x = df_spec.Area.value_counts()
##for index, value in zip(x.index, x):
##    print (index, value)
x
# Out:
# Kitchen                            22
# Bath                               15
# Overhead                           10
# Floors                              9
# Paint & Other Misc Living Areas     8
# Repairs                             4
# General Conditions                  4
# Windows                             1
# Name: Area, dtype: int64

# %%
arr = []

for index, value in zip(x.index, x):
    arr.extend([[index, y] for y in np.linspace(1,value, value).astype(int)])
    
idx_df = pd.DataFrame(arr, columns=['Area', 'idx'])
idx_df.sort_values(by=['Area', 'idx'], inplace=True)
idx_df.reset_index(drop=True, inplace=True)
idx_df.shape
# Out:
# (73, 2)

# %%
df_spec.sort_values(by=['Area', 'Cost center', 'Item'], inplace=True)
df_spec.reset_index(drop=True, inplace=True)

df_spec['idx'] = idx_df.idx
df_spec.head(2)
# Out:
#    Area Cost center                         Item  Category  \
# 0  Bath   3-05-5260  Interior Finish Work, Other     Labor
# 1  Bath   3-05-5270                Bath / Shower  Material
#
#                                            SKU/Spec  \
# 0  Bath Finish Accessories & Misc Carpentry - labor
# 1                   Water-Saving Massage Showerhead
#
#                         Color/Notes Reference  idx
# 0                               DNA       DNA    1
# 1  Brushed Nickel, Brass Ball Joint      LINK    2

# %%
def prep_bid(df_in):
    df = df_in.copy()
    df.drop(['Unnamed: 0'], axis=1, inplace=True)
    df.fillna('DNA', inplace=True) ## DNA: Does Not Apply
    
    upd_ix = [(x,y) for (x,y) in enumerate(df.Area) if y != 'DNA']
    
    for i in range(len(upd_ix) - 1):
        df.Area.iloc[upd_ix[i][0]: upd_ix[i+1][0]] = upd_ix[i][1]

    i = i+1
    df.Area.iloc[upd_ix[i][0]:] = upd_ix[i][1]
    
    df = df.loc[df['Cost center'] != 'DNA',:]
    
    df.sort_values(by=['Area', 'Cost center', 'Item'], inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    x = df_spec.Area.value_counts()
    
    arr = []

    for index, value in zip(x.index, x):
        arr.extend([[index, y] for y in np.linspace(0,value-1, value-1).astype(int)])

    idx_df = pd.DataFrame(arr, columns=['Area', 'idx'])
    idx_df.sort_values(by=['Area', 'idx'], inplace=True)
    idx_df.reset_index(drop=True, inplace=True)
    
    df['idx'] = idx_df.idx
    
    cols_q = [x for x in np.where([x.startswith('Quantity') for x in df.columns])[0]]

    cols = cols_q.copy()

    cols.extend([x + 1 for x in cols_q])
    cols.extend([x + 2 for x in cols_q])
    cols.sort()
    
    k_cols = [0, 1, 2, 3, np.where(['idx' in x for x in df.columns])[0][0]]
    
    lst = list()
    repeat = sum(['Quantity' in x for x in df.columns])
    for i in range(repeat):
        c_cols = k_cols.copy()
        c_cols.extend(cols[3*i:3*i+3])
        ##print(c_cols)
        ##print(i)
        temp_df = pd.DataFrame(df.iloc[:,c_cols]).copy()
        temp_df.columns = ['area', 'cost_center', 'item', 'category', 'idx', 'qty', 'unit','price']
        temp_df.loc[temp_df.price == 'DNA', 'price'] = 0
        temp_df.loc[:, 'price'] = [np.round(x,2) for x in temp_df.price]
        
        temp_df.loc[temp_df.qty.isin(['DNA', 'TBD']), 'qty'] = 0
        temp_df.loc[:, 'qty'] = [np.round(x) for x in temp_df.qty]
        
        temp_df['sp_type'] = 'spec_type_' + str(i)
        
        lst.append(temp_df)
        
    df = pd.concat(lst, axis=0)
    
    ##df.columns = ['area', 'cost_center', 'item', 'category', 'idx', 'qty', 'unit','price', 'spec_type']
    return(df)

# %%
df_bid_rams = pd.read_excel("../data/external/RFP Cost Comparison_Tracker_v9_3.0 Submission 1.6.21.xlsx", 
                   sheet_name='R.A.M.S 2.0', header=6)

df_bid_rams = prep_bid(df_bid_rams)
df_bid_rams['vendor'] = 'RAMS'
df_bid_rams.reset_index(drop=True, inplace=True)

# %%
##df_bid_katerra = pd.read_excel("../data/external/RFP Cost Comparison_Tracker_v9_3.0 Submission 1.6.21.xlsx", 
##                   sheet_name='Katerra', header=12)

#df_bid_katerra = prep_bid(df_bid_katerra)
#df_bid_katerra['vendor'] = 'Katerra'
##df_bid_katerra.head()

# %%
df_bid_pro_craft = pd.read_excel("../data/external/RFP Cost Comparison_Tracker_v9_3.0 Submission 1.6.21.xlsx", 
                   sheet_name='Pro-Craft 2.0', header=12)

df_bid_pro_craft = prep_bid(df_bid_pro_craft)
df_bid_pro_craft['vendor'] = 'Pro-Craft 2.0'
df_bid_pro_craft.reset_index(drop=True, inplace=True)

df_bid_pro_craft.head()
# Out:
#    area cost_center                         item  category  idx   qty  \
# 0  Bath   3-05-5260  Interior Finish Work, Other     Labor  0.0   2.0
# 1  Bath   3-05-5270                Bath / Shower  Material  1.0   2.0
# 2  Bath   3-05-5430                       Vanity  Material  2.0  11.0
# 3  Bath   3-05-5430                       Vanity     Labor  3.0  11.0
# 4  Bath   3-05-5450            Vanity top / sink  Material  4.0  72.0
#
#           unit   price      sp_type         vendor
# 0        Count    0.00  spec_type_0  Pro-Craft 2.0
# 1        Count    0.00  spec_type_0  Pro-Craft 2.0
# 2  Door/Drawer    0.00  spec_type_0  Pro-Craft 2.0
# 3  Door/Drawer  955.43  spec_type_0  Pro-Craft 2.0
# 4         LNIN    0.00  spec_type_0  Pro-Craft 2.0

# %%
final_df = pd.concat([df_bid_rams, df_bid_pro_craft], axis=0)
final_df.reset_index(drop=True, inplace=True)
final_df.shape
# Out:
# (720, 10)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://localhost/TB')

# %%
final_df.to_sql('lvl_bid', con=engine, index=False, if_exists='replace')

# %%
##[x for s in final_df.price if x is not float]
final_df.shape
# Out:
# (720, 10)

# %%
final_df.to_csv("../data/processed/lvl_bid_postgres_load.csv", header=True, index=False)

# %%
import psycopg2

# %%
conn = psycopg2.connect(host="localhost", port = 5432, database="TB")

# %%
cur = conn.cursor()

# %%
cur.execute("""SELECT * FROM lvl_bid""")
query_results = cur.fetchall()
query_results
# Out:
# [('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   300.33,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   11.0,
#   'Door/Drawer',
#   592.74,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   11.0,
#   'Door/Drawer',
#   523.26,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   72.0,
#   'LNIN',
#   211.38,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   72.0,
#   'LNIN',
#   563.92,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   2.0,
#   'Count',
#   149.1,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   2.0,
#   'Count',
#   664.53,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   2.0,
#   'Count',
#   145.3,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   2.0,
#   'Count',
#   56.7,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   2.0,
#   'Count',
#   151.92,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   78.55,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   1096.0,
#   'SQFT',
#   1134.69,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   1096.0,
#   'SQFT',
#   2785.19,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   822.0,
#   'LNFT',
#   152.81,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   375.0,
#   'SQFT',
#   605.28,
#   'spec_type_0',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   1086.37,
#   'spec_type_0',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   295.71,
#   'spec_type_0',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   554.45,
#   'spec_type_0',
#   'RAMS'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   1.0,
#   'Count',
#   181.51,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   34.0,
#   'SQFT',
#   318.81,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   34.0,
#   'SQFT',
#   478.21,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   28.0,
#   'Door/Drawer',
#   1392.74,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   28.0,
#   'Door/Drawer',
#   949.5,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   207.0,
#   'LNIN',
#   508.1,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   207.0,
#   'LNIN',
#   1185.57,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   273.94,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   137.91,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   194.81,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   153.33,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   81.19,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   207.92,
#   'spec_type_0',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   39.27,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   519.8,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   1039.6,
#   'spec_type_0',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   519.8,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   30.03,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   14.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   6.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   28.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   1096.0,
#   'SQFT',
#   894.6,
#   'spec_type_0',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   1096.0,
#   'SQFT',
#   1671.12,
#   'spec_type_0',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_0',
#   'RAMS'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   739.56,
#   'spec_type_0',
#   'RAMS'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   275.5,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   2.0,
#   'Count',
#   46.62,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   6.0,
#   'Door/Drawer',
#   319.68,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   6.0,
#   'Door/Drawer',
#   398.42,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   48.0,
#   'LNIN',
#   129.27,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   48.0,
#   'LNIN',
#   366.49,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   2.0,
#   'Count',
#   136.77,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   2.0,
#   'Count',
#   184.63,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   2.0,
#   'Count',
#   609.6,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   2.0,
#   'Count',
#   326.36,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   2.0,
#   'Count',
#   133.29,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   2.0,
#   'Count',
#   83.21,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   2.0,
#   'Count',
#   52.01,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   2.0,
#   'Count',
#   139.36,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   72.05,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   946.0,
#   'SQFT',
#   898.44,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   946.0,
#   'SQFT',
#   2205.29,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   710.0,
#   'LNFT',
#   120.99,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   375.0,
#   'SQFT',
#   555.24,
#   'spec_type_1',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   873.23,
#   'spec_type_1',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   271.26,
#   'spec_type_1',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   508.62,
#   'spec_type_1',
#   'RAMS'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   1.0,
#   'Count',
#   166.5,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   34.0,
#   'SQFT',
#   288.22,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   34.0,
#   'SQFT',
#   432.33,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   22.0,
#   'Door/Drawer',
#   1082.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   22.0,
#   'Door/Drawer',
#   767.17,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   204.0,
#   'LNIN',
#   459.35,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   204.0,
#   'LNIN',
#   1071.81,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   3.0,
#   'Count',
#   199.28,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   126.51,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   178.7,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   140.65,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   74.48,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   190.73,
#   'spec_type_1',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   36.03,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   476.83,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   953.66,
#   'spec_type_1',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   476.83,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   27.55,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   69.76,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   14.0,
#   'Count',
#   309.87,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   0.78,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   6.0,
#   'Count',
#   2.59,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   28.0,
#   'Count',
#   400.62,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   946.0,
#   'SQFT',
#   739.68,
#   'spec_type_1',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   946.0,
#   'SQFT',
#   1323.18,
#   'spec_type_1',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_1',
#   'RAMS'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   680.83,
#   'spec_type_1',
#   'RAMS'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   142.14,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   1.0,
#   'Count',
#   24.06,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   4.0,
#   'Door/Drawer',
#   236.83,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   4.0,
#   'Door/Drawer',
#   220.87,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   30.0,
#   'LNIN',
#   83.37,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   30.0,
#   'LNIN',
#   227.99,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   1.0,
#   'Count',
#   70.57,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   1.0,
#   'Count',
#   95.26,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   1.0,
#   'Count',
#   338.81,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   1.0,
#   'Count',
#   168.39,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   68.77,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   42.93,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   1.0,
#   'Count',
#   26.84,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   71.9,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   37.18,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   896.0,
#   'SQFT',
#   878.08,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   896.0,
#   'SQFT',
#   2155.34,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   672.0,
#   'LNFT',
#   118.25,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   315.0,
#   'SQFT',
#   488.97,
#   'spec_type_2',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   858.65,
#   'spec_type_2',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   279.91,
#   'spec_type_2',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   524.84,
#   'spec_type_2',
#   'RAMS'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   1.0,
#   'Count',
#   114.54,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   34.0,
#   'SQFT',
#   297.41,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   34.0,
#   'SQFT',
#   446.11,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   22.0,
#   'Door/Drawer',
#   1202.38,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   22.0,
#   'Door/Drawer',
#   752.27,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   204.0,
#   'LNIN',
#   473.99,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   204.0,
#   'LNIN',
#   1105.99,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   205.64,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   130.54,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   185.14,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   145.14,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   76.85,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   196.81,
#   'spec_type_2',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   37.18,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   492.04,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   984.07,
#   'spec_type_2',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   492.04,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   28.43,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   71.98,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   12.0,
#   'Count',
#   274.07,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   0.8,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   5.0,
#   'Count',
#   2.23,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   25.0,
#   'Count',
#   365.81,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   896.0,
#   'SQFT',
#   721.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   896.0,
#   'SQFT',
#   1293.2,
#   'spec_type_2',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_2',
#   'RAMS'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   621.68,
#   'spec_type_2',
#   'RAMS'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   144.32,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   1.0,
#   'Count',
#   24.42,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   3.0,
#   'Door/Drawer',
#   193.75,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   3.0,
#   'Door/Drawer',
#   215.37,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   24.0,
#   'LNIN',
#   67.72,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   24.0,
#   'LNIN',
#   191.98,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   1.0,
#   'Count',
#   71.65,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   1.0,
#   'Count',
#   96.72,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   1.0,
#   'Count',
#   343.99,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   1.0,
#   'Count',
#   170.96,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   69.82,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   43.59,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   1.0,
#   'Count',
#   27.25,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   73.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   37.75,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   772.0,
#   'SQFT',
#   768.14,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   772.0,
#   'SQFT',
#   1885.48,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   579.0,
#   'LNFT',
#   103.45,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   350.0,
#   'SQFT',
#   546.19,
#   'spec_type_3',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   764.97,
#   'spec_type_3',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   284.2,
#   'spec_type_3',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   532.87,
#   'spec_type_3',
#   'RAMS'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   1.0,
#   'Count',
#   116.29,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   35.0,
#   'SQFT',
#   310.84,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   35.0,
#   'SQFT',
#   466.26,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   27.0,
#   'Door/Drawer',
#   1609.61,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   27.0,
#   'Door/Drawer',
#   878.13,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   207.0,
#   'LNIN',
#   488.33,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   207.0,
#   'LNIN',
#   1139.43,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   24.0,
#   'Count',
#   252.91,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   132.54,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   187.97,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   147.36,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   78.03,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   199.83,
#   'spec_type_3',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   37.75,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   499.57,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   999.13,
#   'spec_type_3',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   499.57,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   28.86,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   73.08,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   8.0,
#   'Count',
#   185.51,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   0.82,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   5.0,
#   'Count',
#   2.26,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   21.0,
#   'Count',
#   295.92,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   772.0,
#   'SQFT',
#   669.14,
#   'spec_type_3',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   772.0,
#   'SQFT',
#   1131.29,
#   'spec_type_3',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'RAMS'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   623.11,
#   'spec_type_3',
#   'RAMS'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   143.86,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   1.0,
#   'Count',
#   24.35,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   0.0,
#   'Door/Drawer',
#   213.75,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   0.0,
#   'Door/Drawer',
#   213.58,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   0.0,
#   'LNIN',
#   67.5,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   0.0,
#   'LNIN',
#   191.37,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   1.0,
#   'Count',
#   71.42,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   1.0,
#   'Count',
#   96.41,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   1.0,
#   'Count',
#   342.9,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   1.0,
#   'Count',
#   170.42,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   69.6,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   43.45,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   1.0,
#   'Count',
#   27.16,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   66.4,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   37.63,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   708.0,
#   'SQFT',
#   702.23,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   708.0,
#   'SQFT',
#   1723.68,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   531.0,
#   'LNFT',
#   94.57,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   315.0,
#   'SQFT',
#   494.88,
#   'spec_type_4',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   707.59,
#   'spec_type_4',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   283.3,
#   'spec_type_4',
#   'RAMS'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   531.18,
#   'spec_type_4',
#   'RAMS'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   1.0,
#   'Count',
#   115.93,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   41.0,
#   'SQFT',
#   362.97,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   41.0,
#   'SQFT',
#   544.46,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   26.0,
#   'Door/Drawer',
#   1709.97,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   26.0,
#   'Door/Drawer',
#   854.32,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   249.0,
#   'LNIN',
#   585.54,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   249.0,
#   'LNIN',
#   1366.27,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   30.0,
#   'Count',
#   245.61,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   132.12,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   187.37,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   146.89,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   77.78,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   199.19,
#   'spec_type_4',
#   'RAMS'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   37.63,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   497.98,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   995.97,
#   'spec_type_4',
#   'RAMS'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   497.98,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   28.77,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   72.85,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   8.0,
#   'Count',
#   184.92,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   0.81,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   5.0,
#   'Count',
#   2.26,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   21.0,
#   'Count',
#   294.98,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   708.0,
#   'SQFT',
#   646.12,
#   'spec_type_4',
#   'RAMS'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   708.0,
#   'SQFT',
#   1034.21,
#   'spec_type_4',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'RAMS'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   628.31,
#   'spec_type_4',
#   'RAMS'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   11.0,
#   'Door/Drawer',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   11.0,
#   'Door/Drawer',
#   955.43,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   72.0,
#   'LNIN',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   72.0,
#   'LNIN',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   2.0,
#   'Count',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   1096.0,
#   'SQFT',
#   1634.11,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   1096.0,
#   'SQFT',
#   2152.86,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   822.0,
#   'LNFT',
#   1343.38,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   375.0,
#   'SQFT',
#   589.29,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   976.25,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   392.86,
#   'spec_type_0',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
# ...
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   976.25,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   392.86,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   281.75,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   35.0,
#   'SQFT',
#   100.86,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   35.0,
#   'SQFT',
#   603.43,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   27.0,
#   'Door/Drawer',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   27.0,
#   'Door/Drawer',
#   3922.51,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   207.0,
#   'LNIN',
#   1716.79,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   207.0,
#   'LNIN',
#   1206.86,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   24.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   248.93,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   150.86,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   331.34,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   171.68,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   301.71,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   75.43,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   60.09,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   164.81,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   8.0,
#   'Count',
#   412.03,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   4.12,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   5.0,
#   'Count',
#   10.9,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   21.0,
#   'Count',
#   396.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   772.0,
#   'SQFT',
#   446.36,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   772.0,
#   'SQFT',
#   1213.14,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_3',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5270',
#   'Bath / Shower',
#   'Material',
#   1.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Material',
#   2.0,
#   3.0,
#   'Door/Drawer',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5430',
#   'Vanity',
#   'Labor',
#   3.0,
#   3.0,
#   'Door/Drawer',
#   553.14,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   4.0,
#   1.0,
#   'LNIN',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Labor',
#   5.0,
#   1.0,
#   'LNIN',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5450',
#   'Vanity top / sink',
#   'Material',
#   6.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5470',
#   'Mirror',
#   'Material',
#   7.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   8.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5640',
#   'Toliet',
#   'Material',
#   9.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5660',
#   'Faucet',
#   'Material',
#   10.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5670',
#   'Accessories',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5670',
#   'Shower Rod',
#   'Material',
#   12.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Bath',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   0.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5110',
#   'LVT',
#   'Material',
#   1.0,
#   708.0,
#   'SQFT',
#   1107.88,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5110',
#   'LVT Install',
#   'Labor',
#   2.0,
#   708.0,
#   'SQFT',
#   1390.71,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5120',
#   'Tile',
#   '--',
#   3.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5130',
#   'Carpet',
#   '--',
#   4.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5140',
#   'Baseboard',
#   '--',
#   5.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5150',
#   'Hardwood',
#   '--',
#   6.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5160',
#   'Quarter Round ',
#   'Material',
#   8.0,
#   531.0,
#   'LNFT',
#   867.81,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5170',
#   'Repairs',
#   '--',
#   0.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Floors',
#   '3-05-5180',
#   'Remove existing hard floors',
#   'Labor',
#   1.0,
#   315.0,
#   'SQFT',
#   495.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1310',
#   'Demo',
#   'General Conditions',
#   3.0,
#   1.0,
#   'Floorplan',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1320',
#   'Site prep',
#   'General Conditions',
#   0.0,
#   1.0,
#   'Floorplan',
#   976.25,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-01-1330',
#   'Waste hauling',
#   'General Conditions',
#   1.0,
#   1.0,
#   'Floorplan',
#   392.86,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('General Conditions',
#   '3-06-6010',
#   'Cleaning',
#   'General Conditions',
#   2.0,
#   1.0,
#   'Floorplan',
#   281.75,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5260',
#   'Interior Finish Work, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash',
#   'Material',
#   4.0,
#   41.0,
#   'SQFT',
#   113.74,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5310',
#   'Backsplash Install',
#   'Labor',
#   5.0,
#   41.0,
#   'SQFT',
#   603.43,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets',
#   'Material',
#   6.0,
#   26.0,
#   'Door/Drawer',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5410',
#   'Cabinets Install',
#   'Labor',
#   7.0,
#   26.0,
#   'Door/Drawer',
#   3872.22,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops',
#   'Material',
#   8.0,
#   249.0,
#   'LNIN',
#   3004.38,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5420',
#   'Countertops Install',
#   'Labor',
#   9.0,
#   249.0,
#   'LNIN',
#   1206.86,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5440',
#   'Hardware',
#   'Material',
#   10.0,
#   30.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5510',
#   'Range / Oven',
#   'Material',
#   11.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5520',
#   'Range vent',
#   '--',
#   12.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5530',
#   'Garbage disposal',
#   '--',
#   13.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5540',
#   'Dishwasher',
#   'Material',
#   14.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5550',
#   'Refrigerator',
#   'Material',
#   15.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5560',
#   'Washer Dryer',
#   '0',
#   16.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5570',
#   'Microwave',
#   'Material',
#   17.0,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5590',
#   'Cooktop',
#   'DNA',
#   18.0,
#   0.0,
#   '0',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5610',
#   'Sink',
#   'Material',
#   19.0,
#   1.0,
#   'Count',
#   248.93,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5620',
#   'Finish Plumbing, Other',
#   'Labor',
#   21.0,
#   0.0,
#   'DNA',
#   150.86,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5630',
#   'Faucet',
#   'Material',
#   0.0,
#   1.0,
#   'Count',
#   331.34,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5710',
#   'Light fixture',
#   'Material',
#   1.0,
#   1.0,
#   'IN',
#   171.68,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Appliances, Other',
#   'Labor',
#   2.0,
#   0.0,
#   'Count',
#   301.71,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Kitchen',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   0.0,
#   'DNA',
#   75.43,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8010',
#   'Superintendent',
#   'Overhead',
#   4.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8020',
#   'Laborers',
#   'Overhead',
#   5.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8050',
#   'Lost Time',
#   'Overhead',
#   6.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8090',
#   'Other',
#   'Overhead',
#   7.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8450',
#   'Licenses and Insurance',
#   'DNA',
#   9.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8470',
#   'Travel',
#   'Overhead',
#   0.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-8530',
#   'Operating Expenses',
#   'Overhead',
#   1.0,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-9000',
#   'Profit',
#   'DNA',
#   2.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Overhead',
#   '5-01-9010',
#   'Contingency',
#   'DNA',
#   3.0,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5710',
#   'Light Fixture',
#   'Material',
#   4.0,
#   1.0,
#   'Count',
#   60.09,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   5.0,
#   3.0,
#   'Count',
#   164.81,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Electrical Outlet',
#   'Material',
#   7.0,
#   8.0,
#   'Count',
#   412.03,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   0.0,
#   4.0,
#   'Count',
#   4.12,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5711',
#   'Wall Plate',
#   'Material',
#   1.0,
#   5.0,
#   'Count',
#   10.9,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5720',
#   'Finish Electrical, Other',
#   'Labor',
#   3.0,
#   21.0,
#   'Count',
#   396.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Material',
#   None,
#   708.0,
#   'SQFT',
#   446.36,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Paint & Other Misc Living Areas',
#   '3-05-5910',
#   'Paint',
#   'Labor',
#   None,
#   708.0,
#   'SQFT',
#   1112.57,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-04-4550',
#   'Doors',
#   'Material & Labor',
#   None,
#   1.0,
#   'Count',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-05-5010',
#   'Drywall',
#   'Material & Labor',
#   None,
#   0.0,
#   'SQFT',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Repairs',
#   '3-05-5210',
#   'Molding',
#   'DNA',
#   None,
#   0.0,
#   'DNA',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0'),
#  ('Windows',
#   '3-04-4580',
#   'Window Treatments',
#   'DNA',
#   None,
#   0.0,
#   '-',
#   0.0,
#   'spec_type_4',
#   'Pro-Craft 2.0')]

# %%
df_summ = pd.read_sql_query("SELECT vendor, area, sum(price) FROM lvl_bid group by vendor, area", conn)
df_unit = pd.read_sql_query("SELECT vendor, sp_type, area, sum(price) FROM lvl_bid group by vendor, sp_type, area", conn)

# %%
##df.to_json()

# %%
units = df_unit.sp_type.unique()
units = np.hstack([units, ['All Units']])
units.sort()
units[0]
# Out:
# 'All Units'

# %%
mask = df["sp_type"] == 'spec_type_3'
##mask

# %%
import plotly.express as px
fig = px.bar(df_summ, x="vendor", y="sum", color="area", barmode="group")
fig.show()
# Out:
# <div>                            <div id="e8d17072-2399-4c21-a4f5-bdf8783efab1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8d17072-2399-4c21-a4f5-bdf8783efab1")) {                    Plotly.newPlot(                        "e8d17072-2399-4c21-a4f5-bdf8783efab1",                        [{"alignmentgroup": "True", "hovertemplate": "area=Windows<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Windows", "marker": {"color": "#636efa"}, "name": "Windows", "offsetgroup": "Windows", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [0.0, 3293.49], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=General Conditions<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "General Conditions", "marker": {"color": "#EF553B"}, "name": "General Conditions", "offsetgroup": "General Conditions", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [8254.3, 8357.15], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Overhead<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Overhead", "marker": {"color": "#00cc96"}, "name": "Overhead", "offsetgroup": "Overhead", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [9944.869999999997, 0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Floors<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Floors", "marker": {"color": "#ab63fa"}, "name": "Floors", "offsetgroup": "Floors", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [23542.190000000002, 18417.19], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Bath<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Bath", "marker": {"color": "#FFA15A"}, "name": "Bath", "offsetgroup": "Bath", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [3369.1399999999994, 12118.99], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Paint & Other Misc Living Areas<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Paint & Other Misc Living Areas", "marker": {"color": "#19d3f3"}, "name": "Paint & Other Misc Living Areas", "offsetgroup": "Paint & Other Misc Living Areas", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [15581.960000000001, 12879.100000000002], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Kitchen<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Kitchen", "marker": {"color": "#FF6692"}, "name": "Kitchen", "offsetgroup": "Kitchen", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [29297.890000000007, 45802.63], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Repairs<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Repairs", "marker": {"color": "#B6E880"}, "name": "Repairs", "offsetgroup": "Repairs", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [0.0, 0.0], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "area"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {" ...

# %%
mask = df_unit["sp_type"] == units[1]
fig = px.bar(df_unit[mask], x="vendor", y="sum", color="area", barmode="group")
fig.show()
# Out:
# <div>                            <div id="19010414-47ab-43f4-8a37-f4863c89ed6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19010414-47ab-43f4-8a37-f4863c89ed6f")) {                    Plotly.newPlot(                        "19010414-47ab-43f4-8a37-f4863c89ed6f",                        [{"alignmentgroup": "True", "hovertemplate": "area=Bath<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Bath", "marker": {"color": "#636efa"}, "name": "Bath", "offsetgroup": "Bath", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [955.43, 3437.7300000000005], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Kitchen<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Kitchen", "marker": {"color": "#EF553B"}, "name": "Kitchen", "offsetgroup": "Kitchen", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [6102.8099999999995, 8879.609999999999], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=General Conditions<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "General Conditions", "marker": {"color": "#00cc96"}, "name": "General Conditions", "offsetgroup": "General Conditions", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Pro-Craft 2.0", "RAMS"], "xaxis": "x", "y": [1650.8600000000001, 1936.53], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Repairs<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Repairs", "marker": {"color": "#ab63fa"}, "name": "Repairs", "offsetgroup": "Repairs", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [0.0, 0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Floors<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Floors", "marker": {"color": "#FFA15A"}, "name": "Floors", "offsetgroup": "Floors", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [4677.97, 5719.64], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Paint & Other Misc Living Areas<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Paint & Other Misc Living Areas", "marker": {"color": "#19d3f3"}, "name": "Paint & Other Misc Living Areas", "offsetgroup": "Paint & Other Misc Living Areas", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [2595.75, 3659.8], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Windows<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Windows", "marker": {"color": "#FF6692"}, "name": "Windows", "offsetgroup": "Windows", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [739.56, 0.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "area=Overhead<br>vendor=%{x}<br>sum=%{y}<extra></extra>", "legendgroup": "Overhead", "marker": {"color": "#B6E880"}, "name": "Overhead", "offsetgroup": "Overhead", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["RAMS", "Pro-Craft 2.0"], "xaxis": "x", "y": [2079.2, 0.0], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "area"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width":  ...
