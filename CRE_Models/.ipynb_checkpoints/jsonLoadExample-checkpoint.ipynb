# %%
import re
import json
from pprint import pprint

# %%
def read_mongoextjson_file(filename):
    with open(filename, "r") as f:
        # read the entire input; in a real application,
        # you would want to read a chunk at a time
        bsondata = '['+f.read()+']'

        # convert the TenGen JSON to Strict JSON
        # here, I just convert the ObjectId and Date structures,
        # but it's easy to extend to cover all structures listed at
        # http://www.mongodb.org/display/DOCS/Mongo+Extended+JSON
        jsondata = re.sub(r'ObjectId\s*\(\"(\S+)\"\)',
                          r'{"$oid": "\1"}',
                          bsondata)
#         print(jsondata)
        jsondata = re.sub(r'ISODate\s*\(\s*(\S+)\s*\)',
                          r'{"$date": \1}',
                          jsondata)
        jsondata = re.sub(r'NumberInt\s*\(\s*(\S+)\s*\)',
                          r'{"$numberInt": "\1"}',
                          jsondata)

        # now we can parse this as JSON, and use MongoDB's object_hook
        # function to get rich Python data structures inside a dictionary
#         data = json.loads(jsondata, object_hook=json_util.object_hook)
        data=json.loads(jsondata)

        return data

# %%
json_data = read_mongoextjson_file('project1.json')
pprint(json_data)
# Out:
# [{'__v': 15,
#   '_id': {'$oid': '60819acd008b0f00184617a8'},
#   'city': 'For Collins',
#   'cost_summary_id': '60819d9d008b0f00184618bd',
#   'current_state': {'bid_package': [{'description': 'With more pics',
#                                      'files': [{'description': '',
#                                                 'is_archived': False,
#                                                 'photo_bucket_path': 'tailorbirdhomes-dev',
#                                                 'photo_file_name': 'projectSummary.pdf',
#                                                 'photo_folder_path': 'Projects/60819acd008b0f00184617a8/cost%20summary%20pdf',
#                                                 'photo_tag': None,
#                                                 'uuid': '3e377b3b-af9a-48f2-9aa8-6354d6678a0d'}],
#                                      'modification_note': {'modification_note': 'Project '
#                                                                                 'state '
#                                                                                 'updated',
#                                                            'modified_by': '',
#                                                            'modified_on': {'$date': '2021-04-22T19:48:26.994Z'}}}],
#                     'modification_note': {'modification_note': 'Updated '
#                                                                'ProjectB2B '
#                                                                'State',
#                                           'modified_by': '',
#                                           'modified_on': {'$date': '2021-04-22T19:48:27.032Z'}},
#                     'state': 'BID_UPLOADED'},
#   'is_deleted': False,
#   'location': '2212 Vermont Drive',
#   'metadata': {'budget': '10000',
#                'end_date': 'Thu, 22 Apr 2021 00:00:00 GMT',
#                'project_owner': 'Atlas Group',
#                'property_url': 'https://www.liveatpinecone.com/',
#                'start_date': 'Thu, 22 Apr 2021 00:00:00 GMT'},
#   'modification_notes': [{'_id': {'$oid': '60819acd008b0f00184617ab'},
#                           'modification_note': 'Project Created',
#                           'modified_by': '',
#                           'modified_on': {'$date': '2021-04-22T15:48:29.843Z'}},
#                          {'_id': {'$oid': '60819d9d008b0f00184618bf'},
#                           'modification_note': 'added CostSummaryId',
#                           'modified_by': None,
#                           'modified_on': {'$date': '2021-04-22T16:00:29.034Z'}}],
#   'name': 'Pinecone',
#   'org_id': 'a7784f29-d40a-4515-8a7c-6f4a682cc68a',
#   'project_floor_plans': [{'area_per_unit': 706,
#                            'bathrooms_per_unit': 1,
#                            'bedrooms_per_unit': 1,
#                            'name': 'Pinyon',
#                            'photo_images': ['b2f6614b-7cbf-48ab-bb9b-4582c20ebc8d'],
#                            'scope_id': None,
#                            'total_units_count': 100,
#                            'units_count': 60,
#                            'uuid': 'e8f837df-c3f3-40a7-a7eb-c2cb7a629079'},
#                           {'area_per_unit': 900,
#                            'bathrooms_per_unit': 2,
#                            'bedrooms_per_unit': 2,
#                            'name': 'Fp-2',
#                            'photo_images': ['9c17ce17-5c30-4ad9-bff7-30478f748a58'],
#                            'scope_id': None,
#                            'total_units_count': 50,
#                            'units_count': 50,
#                            'uuid': '769b6659-a294-4e3a-bff9-6de727cddf9a'},
#                           {'area_per_unit': 1000,
#                            'bathrooms_per_unit': 2,
#                            'bedrooms_per_unit': 2,
#                            'name': 'Fp-1',
#                            'photo_images': [],
#                            'scope_id': None,
#                            'total_units_count': 40,
#                            'units_count': 40,
#                            'uuid': '2c3b9155-da27-4b9c-b90a-cc905b703618'}],
#   'project_images': [{'_id': {'$oid': '60819c87008b0f00184618ab'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': '164297405_10160693619483976_362542860291158659_n.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': 'bb506e00-394a-442c-a606-1c44c23bc678'},
#                      {'_id': {'$oid': '60819c87008b0f00184618ac'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': '164642258_10160693618203976_5016215292778984750_n.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '03b94579-57d8-452b-97cf-0ad3d9faee2e'},
#                      {'_id': {'$oid': '60819c87008b0f00184618ad'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'bath1.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': 'f29b88e9-8a07-4e58-86cb-36cbce26647d'},
#                      {'_id': {'$oid': '60819c87008b0f00184618ae'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'bath2.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': 'f8172cb7-3e7f-430f-85e6-1e1985d93b92'},
#                      {'_id': {'$oid': '60819c87008b0f00184618af'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'kitchen6.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '0ff45c30-b7b2-45b2-9458-963bb400b311'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b0'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'kitchen7.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '153df160-9670-4242-8e9a-cd9e34daa094'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b1'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'kitchen8.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '1240736b-ca67-46b5-999b-eb2f0d6fa953'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b2'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Bath1.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '13b1c634-1e80-4166-bac2-28350263ae48'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b3'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Kitchen1.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '12710e48-9015-4757-ba0e-4518e43c6309'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b4'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Kitchen2.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '129dfcb6-f9da-4645-99ef-159664b62661'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b5'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Kitchen3.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '3ac4363d-e411-431a-95bc-53532b64ba9a'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b6'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone kitchen4.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '4b4288e7-9d43-4689-a76c-40f8413a354b'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b7'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Kitchen5.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '367151e8-6988-4830-ab99-7f58f846e8fa'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b8'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'pinecone-apartments-fort-collins-co-building-photo '
#                                          '(1).jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '42057d11-7c6e-4aa3-b12d-a17382a90f1c'},
#                      {'_id': {'$oid': '60819c87008b0f00184618b9'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'pinecone-apartments-fort-collins-co-building-photo '
#                                          '(10).jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/photos',
#                       'photo_tag': 'photos',
#                       'uuid': '09eafcef-ad02-4224-ab08-2223559e06ab'},
#                      {'_id': {'$oid': '60819d26008b0f00184618ba'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Pinewood 2-2 956.jpg',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/measured-floorplans',
#                       'photo_tag': 'measured-floorplans',
#                       'uuid': '9c17ce17-5c30-4ad9-bff7-30478f748a58'},
#                      {'_id': {'$oid': '60819d26008b0f00184618bb'},
#                       'description': '',
#                       'is_archived': False,
#                       'photo_bucket_path': 'tailorbirdhomes-dev',
#                       'photo_file_name': 'Pinecone Pinyon 1-1 706 measured.png',
#                       'photo_folder_path': 'Projects/60819acd008b0f00184617a8/measured-floorplans',
#                       'photo_tag': 'measured-floorplans',
#                       'uuid': 'b2f6614b-7cbf-48ab-bb9b-4582c20ebc8d'}],
#   'project_state_log': [{'bid_package': [{'_id': {'$oid': '60819acd008b0f00184617a9'},
#                                           'description': '',
#                                           'files': [{'_id': {'$oid': '60819acd008b0f00184617aa'},
#                                                      'description': '',
#                                                      'photo_bucket_path': '',
#                                                      'photo_file_name': '',
#                                                      'photo_folder_path': ''}],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T15:48:29.839Z'}}}],
#                          'modification_note': {'modification_note': 'Project '
#                                                                     'state '
#                                                                     'updated',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T15:48:29.839Z'}},
#                          'state': 'PROJECT_INITIATED'},
#                         {'bid_package': [{'_id': {'$oid': '60819b31008b0f00184618a8'},
#                                           'description': None,
#                                           'files': [],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T15:50:09.275Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T15:50:09.275Z'}},
#                          'state': 'FLOORPLAN_ADDED'},
#                         {'bid_package': [{'_id': {'$oid': '60819bba008b0f00184618a9'},
#                                           'description': None,
#                                           'files': [],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T15:52:26.915Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T15:52:26.915Z'}},
#                          'state': 'FLOORPLAN_ADDED'},
#                         {'bid_package': [{'_id': {'$oid': '60819bbc008b0f00184618aa'},
#                                           'description': None,
#                                           'files': [],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T15:52:28.536Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T15:52:28.536Z'}},
#                          'state': 'FLOORPLAN_ADDED'},
#                         {'bid_package': [{'_id': {'$oid': '60819d69008b0f00184618bc'},
#                                           'description': None,
#                                           'files': [],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T15:59:37.093Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T15:59:37.293Z'}},
#                          'state': 'SCOPE_CONFIRMED'},
#                         {'bid_package': [{'_id': {'$oid': '60819dd4008b0f00184618c0'},
#                                           'description': None,
#                                           'files': [{'_id': {'$oid': '60819dd4008b0f00184618c1'},
#                                                      'description': '',
#                                                      'photo_bucket_path': 'tailorbirdhomes-dev',
#                                                      'photo_file_name': 'projectSummary.pdf',
#                                                      'photo_folder_path': 'Projects/60819acd008b0f00184617a8/cost%20summary%20pdf'}],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T16:01:24.294Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T16:01:24.357Z'}},
#                          'state': 'BID_UPLOADED'},
#                         {'bid_package': [{'_id': {'$oid': '60819deb008b0f00184618c2'},
#                                           'description': None,
#                                           'files': [],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T16:01:47.652Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T16:01:47.819Z'}},
#                          'state': 'BID_APPROVED'},
#                         {'bid_package': [{'_id': {'$oid': '6081d2bb008b0f00184618cc'},
#                                           'description': 'This is newer '
#                                                          'version',
#                                           'files': [{'_id': {'$oid': '6081d2bb008b0f00184618cd'},
#                                                      'description': '',
#                                                      'photo_bucket_path': 'tailorbirdhomes-dev',
#                                                      'photo_file_name': 'projectSummary.pdf',
#                                                      'photo_folder_path': 'Projects/60819acd008b0f00184617a8/cost%20summary%20pdf'}],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T19:47:07.193Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T19:47:07.240Z'}},
#                          'state': 'BID_UPLOADED'},
#                         {'bid_package': [{'_id': {'$oid': '6081d30b008b0f00184618ce'},
#                                           'description': 'With more pics',
#                                           'files': [{'_id': {'$oid': '6081d30b008b0f00184618cf'},
#                                                      'description': '',
#                                                      'photo_bucket_path': 'tailorbirdhomes-dev',
#                                                      'photo_file_name': 'projectSummary.pdf',
#                                                      'photo_folder_path': 'Projects/60819acd008b0f00184617a8/cost%20summary%20pdf'}],
#                                           'modification_note': {'modification_note': 'Project '
#                                                                                      'state '
#                                                                                      'updated',
#                                                                 'modified_by': '',
#                                                                 'modified_on': {'$date': '2021-04-22T19:48:26.994Z'}}}],
#                          'modification_note': {'modification_note': 'Updated '
#                                                                     'ProjectB2B '
#                                                                     'State',
#                                                'modified_by': '',
#                                                'modified_on': {'$date': '2021-04-22T19:48:27.032Z'}},
#                          'state': 'BID_UPLOADED'}],
#   'project_type': 'MULTI_FAMILY',
#   'state': 'CO',
#   'team': [],
#   'user_id': 'a60f2a75-9e0a-4302-8f98-6e49370443b3',
#   'zip_code': ''}]
