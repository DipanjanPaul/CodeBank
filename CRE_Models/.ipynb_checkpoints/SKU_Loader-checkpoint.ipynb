# %%
from datetime import date, time

import pandas as pd
import numpy as np


pd.options.display.max_columns = 100
pd.options.display.max_rows = 300
pd.options.display.max_colwidth = 50

# %% [markdown]
# ### The following section has been developed to created a rule table for the spec metadata. This logic is tuned to the XL created by Ashish. If work continues in this drirection to capture spec metadata, this section of the code will be useful

# %%
df_md = pd.read_excel("../data/external/New SKUs and SKUs Meta Data v1.0.xlsx", 
                   sheet_name='SKU Tags Meta Data', header=1)

df_md.rename(columns={'Unnamed: 0':'Area', 'Unnamed: 1':'Scope'}, inplace=True)
df_md.drop([x for i,x in enumerate(df_md.columns.values) if x.startswith('Un')], inplace=True, axis=1)
df_md.fillna("UNK", inplace=True)

df_md.head()
# Out:
#       Area            Scope      name       possible values    name.1  \
# 0  Kitchen         Cabinets     style     shaker, flat face  material
# 1  Kitchen  Cabinet - Paint  material                   UNK    finish
# 2  Kitchen         Counters  material                   UNK    finish
# 3  Kitchen             Sink    basins                   UNK     holes
# 4  Kitchen           Faucet     style  pull down, down flex     holes
#
#            possible values.1     name.2 possible values.2
# 0  all wood, mdf, thermofoil     finish  painted, stained
# 1                        UNK        UNK               UNK
# 2                        UNK  thickness               UNK
# 3                        UNK      mount               UNK
# 4                        UNK        UNK               UNK

# %%
m_lst = []

for idx in range(2):
    temp = df_md[['Area', 'Scope']].copy()
    temp['tag'] = df_md.iloc[:,idx*2 + 2]
    temp['value'] = df_md.iloc[:,idx*2 + 3]

    lst = []

    for i in temp.index:
        for v_cnt in range(len(temp.value[i].split(','))):
            l1 = [x for x in temp.iloc[i,0:3].values]
            l2 = [temp.value[i].split(',')[v_cnt].strip()]

            l1.extend((l2))

            if np.sum([x == 'UNK' for x in l1]) < 4:
                lst.append(l1)

        temp_df = pd.DataFrame(lst)
        temp_df.columns = ['Area', 'Scope', 'Tag', 'Value']
        
    m_lst.append(temp_df)

# %%
f_df = pd.concat(m_lst, axis=0)
f_df.head()
# Out:
#       Area            Scope       Tag      Value
# 0  Kitchen         Cabinets     style     shaker
# 1  Kitchen         Cabinets     style  flat face
# 2  Kitchen  Cabinet - Paint  material        UNK
# 3  Kitchen         Counters  material        UNK
# 4  Kitchen             Sink    basins        UNK

# %% [markdown]
# ### The following code has been created to load a Postgres table with a structured schema and will contain the SKU data.

# %%
df_ext = pd.read_excel("../data/external/lightning bid master template v3 price data.xlsm", 
                   sheet_name='Price Data', header=1)

df_ext.drop([x for x in df_ext.columns if x.startswith('Unnamed: ')], axis=1, inplace=True)
df_ext.columns = [x.replace(' ', '_') for x in df_ext.columns]
df_ext.columns = [x.replace('(', '') for x in df_ext.columns]
df_ext.columns = [x.replace(')', '') for x in df_ext.columns]
df_ext.columns = [x.replace('#', '') for x in df_ext.columns]

df_ext.drop(np.where(df_ext.Category.isnull() == True)[0], axis=0, inplace=True)

df_ext.reset_index(inplace=True, drop=True)

df_ext.RFP_Notes = df_ext.RFP_Notes.astype('object')
df_ext.Catalogue_ID_ = df_ext.Catalogue_ID_.astype('object')

key_fields = ['Category', 'Sub_Category', 'Work_Type', 'RFP_SPEC', 'RFP_SPEC_Tags']

other_required_fields = ['RFP_Notes', 'Owner', 'Property_Manager', 'Geography', 'Manufacture',
       'SKU_', 'Supplier', 'Catalogue_ID_', 'Retail_Name', 'Brandline', 'Notes', 'URL']

tag_fields = ['Color', 'Style_A', 'Style_B', 'Material', 'Finish',
       'Quality', 'Defining_Size', 'Tailorbird_Catalogue', 'Takeoff_Codex', 'Unit']

numeric_fields = ['Price']

info_fields = ['Price_Notes', 'Price_Source_Notes', 'Archive_Name']

df_ext.loc[:,key_fields] = df_ext[key_fields].fillna('ALL', axis=1)
df_ext.loc[:,other_required_fields] = df_ext[other_required_fields].fillna('ANY',  axis=1)
df_ext.loc[:,tag_fields] = df_ext[tag_fields].fillna('DNA', axis=1)
df_ext.loc[:,numeric_fields] = df_ext[numeric_fields].fillna(0, axis=1)
df_ext.loc[:,info_fields] = df_ext[info_fields].fillna('MI', axis=1)

df_ext = df_ext.apply(lambda x: x.str.upper(), axis=1)

df_ext.head(2)
# Out:
#   Category             Sub_Category Work_Type  \
# 0  KITCHEN       CABINET - BOX SETS  MATERIAL
# 1  KITCHEN  CABINET - FRONTS, DOORS  MATERIAL
#
#                                 RFP_SPEC                    RFP_SPEC_Tags  \
# 0       CABINET - BOX SETS, WOOD, SHAKER  SUB CATEGORY, MATERIAL, STYLE A
# 1  CABINET - FRONTS, DOORS, WOOD, SHAKER  SUB CATEGORY, MATERIAL, STYLE A
#
#   RFP_Notes                   Owner Property_Manager            Geography  \
# 0       ANY                     ANY              ANY                  ANY
# 1       ANY  CATALYST HOUSING GROUP     GREYSTAR NCA  NORTHERN CALIFORNIA
#
#   Manufacture SKU_ Supplier Catalogue_ID_ Retail_Name Brandline  \
# 0         ANY  ANY      ANY           ANY         ANY       ANY
# 1         ANY  ANY      ANY           ANY         ANY       ANY
#
#                         Notes  URL  Color Style_A Style_B Material   Finish  \
# 0  INCLUDES UPPERS AND LOWERS  ANY  WHITE  SHAKER     DNA     WOOD  PAINTED
# 1                         ANY  ANY    DNA  SHAKER     DNA     WOOD      DNA
#
#   Quality Defining_Size Tailorbird_Catalogue Takeoff_Codex   Unit  Price  \
# 0     DNA           DNA                  DNA             A   LNIN    NaN
# 1     DNA           DNA                  DNA           B+C  COUNT    NaN
#
#          Price_Notes Price_Source_Notes  \
# 0  SHIPPING INCLUDED                 MI
# 1                 MI       SERENITY RFP
#
#                                     Archive_Name
# 0        H1 KITCHEN CABINETS WOOD SHAKER - LNIN
# 1  H2 KITCHEN CABINETS WOOD SHAKER - NEW FRONTS

# %%
df_ext = df_ext[-(df_ext.Sub_Category.str.contains('Exclude'))]
df_ext.reset_index(drop=True, inplace=True)

##df_ext['spec'] = df_ext.Sub_Category.apply(lambda x: 'DNA' if len(x.split(' - ')) == 1 else x.split(' - ')[1].upper() )
##df_ext['scope'] = df_ext.Sub_Category.apply(lambda x: x.split(' - ')[0].upper() )

##df_ext.rename(columns={'Category':'area'}, inplace=True)
##df_ext.drop(['Sub_Category'], inplace=True, axis=1)

##df_ext = df_ext.reindex(['area', 'scope', 'spec',
##                'Work_Type', 'RFP_SPEC', 'RFP_SPEC_Tags', 'RFP_Notes',
##                'Owner', 'Property_Manager', 'Geography', 'Manufacture', 'SKU_',
##                'Supplier', 'Catalogue_ID_', 'Retail_Name', 'Brandline', 'Notes', 'URL',
##                'Color', 'Style_A', 'Style_B', 'Material', 'Finish', 'Quality',
##                'Defining_Size', 'Tailorbird_Catalogue', 'Takeoff_Codex', 'Unit',
##                'Price', 'Price_Notes', 'Price_Source_Notes', 'Archive_Name' ], axis=1)

# %%
df_ext.columns = [x.lower() for x in df_ext.columns]

df_ext
# Out:
#                     area                    scope  \
# 0                KITCHEN                  CABINET
# 1                KITCHEN                  CABINET
# 2                KITCHEN                  CABINET
# 3                KITCHEN                  CABINET
# 4                KITCHEN                  CABINET
# 5                KITCHEN                  CABINET
# 6                KITCHEN              COUNTERTOPS
# 7                KITCHEN              COUNTERTOPS
# 8                KITCHEN              COUNTERTOPS
# 9                KITCHEN              COUNTERTOPS
# 10               KITCHEN              COUNTERTOPS
# 11               KITCHEN                  CABINET
# 12               KITCHEN                     SINK
# 13               KITCHEN                     SINK
# 14               KITCHEN                     SINK
# 15               KITCHEN                     SINK
# 16               KITCHEN                   FAUCET
# 17               KITCHEN                   FAUCET
# 18               KITCHEN                   FAUCET
# 19               KITCHEN                   FAUCET
# 20               KITCHEN                   FAUCET
# 21               KITCHEN            LIGHT FIXTURE
# 22               KITCHEN               BACKSPLASH
# 23               KITCHEN               BACKSPLASH
# 24               KITCHEN               BACKSPLASH
# 25               KITCHEN               BACKSPLASH
# 26               KITCHEN               BACKSPLASH
# 27               KITCHEN               BACKSPLASH
# 28               KITCHEN               BACKSPLASH
# 29               KITCHEN         GARBAGE DISPOSAL
# 30               KITCHEN                  EXCLUDE
# 31               KITCHEN                  CABINET
# 32               KITCHEN              COUNTERTOPS
# 33               KITCHEN              COUNTERTOPS
# 34               KITCHEN               BACKSPLASH
# 35               KITCHEN               BACKSPLASH
# 36               KITCHEN          FINISH PLUMBING
# 37               KITCHEN        FINISH ELECTRICAL
# 38               KITCHEN        OTHER FINISH WORK
# 39               KITCHEN                  EXCLUDE
# 40            APPLIANCES                  COOKTOP
# 41            APPLIANCES               DISHWASHER
# 42            APPLIANCES               DISHWASHER
# 43            APPLIANCES               DISHWASHER
# 44            APPLIANCES                MICROWAVE
# 45            APPLIANCES                MICROWAVE
# 46            APPLIANCES                MICROWAVE
# 47            APPLIANCES             RANGE / OVEN
# 48            APPLIANCES             RANGE / OVEN
# 49            APPLIANCES             RANGE / OVEN
# 50            APPLIANCES             RANGE / OVEN
# 51            APPLIANCES             REFRIGERATOR
# 52            APPLIANCES             REFRIGERATOR
# 53            APPLIANCES             REFRIGERATOR
# 54            APPLIANCES             REFRIGERATOR
# 55            APPLIANCES             REFRIGERATOR
# 56            APPLIANCES             REFRIGERATOR
# 57            APPLIANCES     WASHER AND DRYER SET
# 58            APPLIANCES                     VENT
# 59            APPLIANCES                     VENT
# 60            APPLIANCES                   DRYER
# 61            APPLIANCES                   WASHER
# 62            APPLIANCES                  EXCLUDE
# 63            APPLIANCES                APPLIANCE
# 64            APPLIANCES                APPLIANCE
# 65            APPLIANCES                APPLIANCE
# 66            APPLIANCES                APPLIANCE
# 67            APPLIANCES                APPLIANCE
# 68            APPLIANCES                APPLIANCE
# 69            APPLIANCES                APPLIANCE
# 70            APPLIANCES                  EXCLUDE
# 71              FLOORING                     LVT
# 72              FLOORING                     LVT
# 73              FLOORING                    VINYL
# 74              FLOORING                   CARPET
# 75              FLOORING                   CARPET
# 76              FLOORING                   CARPET
# 77              FLOORING                   CARPET
# 78              FLOORING                   CARPET
# 79              FLOORING                   CARPET
# 80              FLOORING                   CARPET
# 81              FLOORING                   REPAIR
# 82              FLOORING                BASEBOARD
# 83              FLOORING            QUARTER ROUND
# 84              FLOORING               TILE FLOOR
# 85              FLOORING                 HARDWOOD
# 86              FLOORING                 HARDWOOD
# 87              FLOORING               TILE FLOOR
# 88              FLOORING                    VINYL
# 89              FLOORING                      LVT
# 90              FLOORING                   CARPET
# 91              FLOORING   REMOVE EXISTING FLOORS
# 92              FLOORING   REMOVE EXISTING FLOORS
# 93              FLOORING                  EXCLUDE
# 94                  BATH                   VANITY
# 95                  BATH              VANITY TOP
# 96                  BATH              VANITY TOP
# 97                  BATH                     SINK
# 98                  BATH                   VANITY
# 99                  BATH                   VANITY
# 100                 BATH                   VANITY
# 101                 BATH                   VANITY
# 102                 BATH                   VANITY
# 103                 BATH               SHOWER ROD
# 104                 BATH            LIGHT FIXTURE
# 105                 BATH                   MIRROR
# 106                 BATH              SINK FAUCET
# 107                 BATH              SINK FAUCET
# 108                 BATH                   TOLIET
# 109                 BATH    WALL MOUNTED HARDWARE
# 110                 BATH              SHOWER TRIM
# 111                 BATH              SHOWER TRIM
# 112                 BATH              SHOWER TRIM
# 113                 BATH                 BATH TUB
# 114                 BATH                      ALL
# 115                 BATH               SHOWER PAN
# 116                 BATH  ADD ADDITIONAL BATHROOM
# 117                 BATH                  EXCLUDE
# 118                 BATH                   VANITY
# 119                 BATH               VANITY TOP
# 120                 BATH                   VANITY
# 121                 BATH        FINISH ELECTRICAL
# 122                 BATH          FINISH PLUMBING
# 123                 BATH     BATH/SHOWER SURROUND
# 124                 BATH     BATH/SHOWER SURROUND
# 125                 BATH        OTHER FINISH WORK
# 126                 BATH                  EXCLUDE
# 127                PAINT                    PAINT
# 128                PAINT                    PAINT
# 129                PAINT                    PAINT
# 130                PAINT                    PAINT
# 131                PAINT                  EXCLUDE
# 132  LIGHTS AND FIXTURES              CEILING FAN
# 133  LIGHTS AND FIXTURES            LIGHT FIXTURE
# 134  LIGHTS AND FIXTURES            LIGHT FIXTURE
# 135  LIGHTS AND FIXTURES            LIGHT FIXTURE
# 136  LIGHTS AND FIXTURES        ELECTRICAL OUTLET
# 137  LIGHTS AND FIXTURES        ELECTRICAL OUTLET
# 138  LIGHTS AND FIXTURES               WALL PLATE
# 139  LIGHTS AND FIXTURES               WALL PLATE
# 140  LIGHTS AND FIXTURES                  EXCLUDE
# 141              WINDOWS         WINDOW TREATMENT
# 142              WINDOWS                  EXCLUDE
# 143              REPAIRS                  DRYWALL
# 144              REPAIRS         DOOR PREHUNG KIT
# 145              REPAIRS                BASEBOARD
# 146              REPAIRS                  EXCLUDE
# 147   GENERAL CONDITIONS                SITE PREP
# 148   GENERAL CONDITIONS                     DEMO
# 149   GENERAL CONDITIONS            WASTE HAULING
# 150   GENERAL CONDITIONS                 CLEANING
# 151   GENERAL CONDITIONS                  EXCLUDE
# 152            OVER HEAD           SUPERINTENDENT
# 153            OVER HEAD                 LABORERS
# 154            OVER HEAD                LOST TIME
# 155            OVER HEAD                    OTHER
# 156            OVER HEAD                   TRAVEL
# 157            OVER HEAD       OPERATING EXPENSES
# 158            OVER HEAD                  EXCLUDE
# 159  PROFIT & CONTIGENCY   LICENSES AND INSURANCE
# 160  PROFIT & CONTIGENCY                   PROFIT
# 161  PROFIT & CONTIGENCY              CONTINGENCY
# 162  PROFIT & CONTIGENCY       TAILORBIRD RFP FEE
# 163  PROFIT & CONTIGENCY                  EXCLUDE
#
#                                     spec         work_type  \
# 0                               BOX SETS          MATERIAL
# 1                          FRONTS, DOORS          MATERIAL
# 2                          FRONTS, DOORS          MATERIAL
# 3                               BOX SETS          MATERIAL
# 4    REFINISH AND PAINT BOXES AND FRONTS  LABOR & MATERIAL
# 5               REFINISH AND PAINT BOXES  LABOR & MATERIAL
# 6                                    DNA          MATERIAL
# 7                                    DNA          MATERIAL
# 8                                    DNA          MATERIAL
# 9                                    DNA          MATERIAL
# 10                                   DNA          MATERIAL
# 11              HARDWARE PULLS AND KNOBS          MATERIAL
# 12                                   DNA          MATERIAL
# 13                                   DNA          MATERIAL
# 14                                   DNA          MATERIAL
# 15                                   DNA          MATERIAL
# 16                                   DNA          MATERIAL
# 17                                   DNA          MATERIAL
# 18                                   DNA          MATERIAL
# 19                                   DNA          MATERIAL
# 20                                   DNA          MATERIAL
# 21                               KITCHEN          MATERIAL
# 22                                   DNA          MATERIAL
# 23                                   DNA          MATERIAL
# 24                                   DNA          MATERIAL
# 25                                   DNA          MATERIAL
# 26                                   DNA          MATERIAL
# 27                                   DNA          MATERIAL
# 28                                   DNA          MATERIAL
# 29                                   DNA          MATERIAL
# 30                                    -                ALL
# 31         INSTALL BOX SETS AND HARDWARE             LABOR
# 32                               INSTALL             LABOR
# 33                               INSTALL             LABOR
# 34                               INSTALL             LABOR
# 35                               INSTALL             LABOR
# 36                                   DNA             LABOR
# 37                                   DNA             LABOR
# 38                                   DNA             LABOR
# 39                                    -                ALL
# 40                                   DNA          MATERIAL
# 41                                   DNA          MATERIAL
# 42                                   DNA          MATERIAL
# 43                                   DNA          MATERIAL
# 44                                   DNA          MATERIAL
# 45                                   DNA          MATERIAL
# 46                                   DNA          MATERIAL
# 47                                   DNA          MATERIAL
# 48                                   DNA          MATERIAL
# 49                                   DNA          MATERIAL
# 50                                   DNA          MATERIAL
# 51                                   DNA          MATERIAL
# 52                                   DNA          MATERIAL
# 53                                   DNA          MATERIAL
# 54                                   DNA          MATERIAL
# 55                                   DNA          MATERIAL
# 56                                   DNA          MATERIAL
# 57                                   DNA          MATERIAL
# 58                                   DNA          MATERIAL
# 59                                   DNA          MATERIAL
# 60                                   DNA          MATERIAL
# 61                                   DNA          MATERIAL
# 62                                    -                ALL
# 63                               INSTALL             LABOR
# 64                               INSTALL             LABOR
# 65                               INSTALL             LABOR
# 66                               INSTALL             LABOR
# 67                               INSTALL             LABOR
# 68                               INSTALL             LABOR
# 69                               INSTALL             LABOR
# 70                                    -                ALL
# 71                                   DNA          MATERIAL
# 72                                   DNA          MATERIAL
# 73                                   DNA          MATERIAL
# 74                                   DNA          MATERIAL
# 75                                   DNA          MATERIAL
# 76                                   DNA          MATERIAL
# 77                                   DNA          MATERIAL
# 78                                   DNA          MATERIAL
# 79                                   DNA          MATERIAL
# 80                                   DNA          MATERIAL
# 81                       FLOAT SUBFLOORS  LABOR & MATERIAL
# 82                               INSTALL  MATERIAL & LABOR
# 83                               INSTALL  MATERIAL & LABOR
# 84                              REFINISH  LABOR & MATERIAL
# 85                              REFINISH  LABOR & MATERIAL
# 86                              REFINISH  LABOR & MATERIAL
# 87                               INSTALL             LABOR
# 88                               INSTALL             LABOR
# 89                               INSTALL             LABOR
# 90                               INSTALL             LABOR
# 91                                   DNA             LABOR
# 92                                   DNA             LABOR
# 93                                    -                ALL
# 94                                FRONTS          MATERIAL
# 95                                   DNA          MATERIAL
# 96                                   DNA          MATERIAL
# 97                                   DNA          MATERIAL
# 98                              BOX SETS          MATERIAL
# 99                              BOX SETS          MATERIAL
# 100                             BOX SETS          MATERIAL
# 101                             BOX SETS          MATERIAL
# 102                             BOX SETS          MATERIAL
# 103                                  DNA          MATERIAL
# 104                                 BATH          MATERIAL
# 105                                  DNA          MATERIAL
# 106                                  DNA          MATERIAL
# 107                                  DNA          MATERIAL
# 108                                  DNA          MATERIAL
# 109                                  DNA          MATERIAL
# 110                                  DNA          MATERIAL
# 111                                  DNA          MATERIAL
# 112                                  DNA          MATERIAL
# 113                                  DNA          MATERIAL
# 114                                  DNA          MATERIAL
# 115                             REFINISH  LABOR & MATERIAL
# 116                                  DNA  LABOR & MATERIAL
# 117                                   -                ALL
# 118            INSTALL FRONTS & HARDWARE             LABOR
# 119                              INSTALL             LABOR
# 120          INSTALL BOX SETS & HARDWARE             LABOR
# 121                                  DNA             LABOR
# 122                                  DNA             LABOR
# 123                              INSTALL             LABOR
# 124                             REFINISH  LABOR & MATERIAL
# 125                                  DNA             LABOR
# 126                                   -                ALL
# 127                                WALLS          MATERIAL
# 128                                  DNA             LABOR
# 129                                WALLS          MATERIAL
# 130                                  DNA             LABOR
# 131                                   -                ALL
# 132                                  DNA          MATERIAL
# 133                   BED OR LIVING AREA          MATERIAL
# 134                   BED OR LIVING AREA          MATERIAL
# 135                   BED OR LIVING AREA          MATERIAL
# 136                                  USB          MATERIAL
# 137                                  DNA          MATERIAL
# 138                                  DNA          MATERIAL
# 139                                  DNA          MATERIAL
# 140                                   -                ALL
# 141                                  DNA          MATERIAL
# 142                                   -                ALL
# 143                                  DNA  MATERIAL & LABOR
# 144                                  DNA  MATERIAL & LABOR
# 145                              INSTALL  MATERIAL & LABOR
# 146                                   -                ALL
# 147                                  DNA  LABOR & MATERIAL
# 148                                  DNA  LABOR & MATERIAL
# 149                                  DNA  LABOR & MATERIAL
# 150                                  DNA  LABOR & MATERIAL
# 151                                   -                ALL
# 152                                  DNA          OVERHEAD
# 153                                  DNA          OVERHEAD
# 154                                  DNA          OVERHEAD
# 155                                  DNA          OVERHEAD
# 156                                  DNA          OVERHEAD
# 157                                  DNA          OVERHEAD
# 158                                   -                ALL
# 159                                  DNA          OVERHEAD
# 160                                  DNA          OVERHEAD
# 161                                  DNA          OVERHEAD
# 162                                  DNA          OVERHEAD
# 163                                   -                ALL
#
#                                               rfp_spec  \
# 0                     CABINET - BOX SETS, WOOD, SHAKER
# 1                CABINET - FRONTS, DOORS, WOOD, SHAKER
# 2                      CABINET - FRONTS, DOORS, , FLAT
# 3                     CABINET - BOX SETS, WOOD, SHAKER
# 4    CABINET - REFINISH AND PAINT BOXES AND FRONTS, ,
# 5               CABINET - REFINISH AND PAINT BOXES, ,
# 6                             COUNTERTOPS, GRANITE, L1
# 7                              COUNTERTOPS, QUARTZ, L1
# 8                              COUNTERTOPS, QUARTZ, L1
# 9                             COUNTERTOPS, GRANITE, L2
# 10                             COUNTERTOPS, LAMINATE,
# 11   CABINET - HARDWARE PULLS AND KNOBS, BRUSHED NI...
# 12                                SINK, SS, UNDERMOUNT
# 13                                SINK, SS, UNDERMOUNT
# 14                                SINK, SS, UNDERMOUNT
# 15                                SINK, SS, UNDERMOUNT
# 16                         FAUCET, CHROME, SINGLE HOLE
# 17                         FAUCET, CHROME, SINGLE HOLE
# 18                                    FAUCET, CHROME,
# 19                                     FAUCET, BLACK,
# 20                                    FAUCET, CHROME,
# 21                         LIGHT FIXTURE - KITCHEN, ,
# 22                            BACKSPLASH, TILE, ACCENT
# 23                            BACKSPLASH, TILE, SUBWAY
# 24                            BACKSPLASH, TILE, ACCENT
# 25                            BACKSPLASH, TILE, ACCENT
# 26                            BACKSPLASH, TILE, ACCENT
# 27                            BACKSPLASH, TILE, ACCENT
# 28                 BACKSPLASH, CULTURED MARBLE, ACCENT
# 29                          GARBAGE DISPOSAL, 1/3 HP,
# 30                                                 ALL
# 31   CABINET - INSTALL BOX SETS AND HARDWARE, , INC...
# 32     COUNTERTOPS - INSTALL, STONE OR SOLID SURFACE,
# 33                    COUNTERTOPS - INSTALL, LAMINTE,
# 34                        BACKSPLASH - INSTALL, TILE,
# 35                        BACKSPLASH - INSTALL, TILE,
# 36                                 FINISH PLUMBING, ,
# 37                               FINISH ELECTRICAL, ,
# 38                               OTHER FINISH WORK, ,
# 39                                                 ALL
# 40                                    COOKTOP, , BLACK
# 41                               DISHWASHER, AMANA, SS
# 42                          DISHWASHER, FRIGIDAIRE, SS
# 43                             DISHWASHER, SAMSUNG, SS
# 44                                MICROWAVE, AMANA, SS
# 45                           MICROWAVE, FRIGIDAIRE, SS
# 46                              MICROWAVE, SAMSUNG, SS
# 47                             RANGE / OVEN, AMANA, SS
# 48                         RANGE / OVEN, WHIRLPOOL, SS
# 49                        RANGE / OVEN, FRIGIDAIRE, SS
# 50                           RANGE / OVEN, SAMSUNG, SS
# 51                             REFRIGERATOR, AMANA, SS
# 52                     REFRIGERATOR, FRIGIDAIRE, BLACK
# 53                        REFRIGERATOR, FRIGIDAIRE, SS
# 54                           REFRIGERATOR, SAMSUNG, SS
# 55                      REFRIGERATOR, WHIRLPOOL, BLACK
# 56                         REFRIGERATOR, WHIRLPOOL, SS
# 57                       WASHER AND DRYER SET, , WHITE
# 58                                VENT, FRIGIDAIRE, SS
# 59                                 VENT, WHIRLPOOL, SS
# 60                              DRYER , SAMSUNG, WHITE
# 61                              WASHER, SAMSUNG, WHITE
# 62                                                 ALL
# 63                   APPLIANCE - INSTALL, DISHWASHER,
# 64   APPLIANCE - INSTALL, SET OF APPLIANCES, INCLUD...
# 65   APPLIANCE - INSTALL, REFRIDGERATOR, INCLUDES I...
# 66                    APPLIANCE - INSTALL, MICROWAVE,
# 67                        APPLIANCE - INSTALL, RANGE,
# 68                 APPLIANCE - INSTALL, WASHER/DRYER,
# 69                         APPLIANCE - INSTALL, VENT,
# 70                                                 ALL
# 71                           LVT , SHAW, MARKET SQUARE
# 72                          LVT , MOHAWK, BALDORIA II
# 73                                           VINYL, ,
# 74                        CARPET, MOHAWK, HIGH VOLTAGE
# 75                        CARPET, MOHAWK, HIGH VOLTAGE
# 76                    CARPET, MOHAWK, ENRICHED TEXTURE
# 77                        CARPET, MOHAWK, HIGH VOLTAGE
# 78                    CARPET, MOHAWK, ENRICHED TEXTURE
# 79                        CARPET, MOHAWK, HIGH VOLTAGE
# 80                    CARPET, MOHAWK, ENRICHED TEXTURE
# 81                        REPAIR - FLOAT SUBFLOORS, ,
# 82                             BASEBOARD - INSTALL, ,
# 83                         QUARTER ROUND - INSTALL, ,
# 84             TILE FLOOR - REFINISH, CLEAN AND RESEAL
# 85              HARDWOOD - REFINISH, BUFF AND REFINISH
# 86                  HARDWOOD - REFINISH, SAND REFINISH
# 87                        TILE FLOOR - INSTALL, TILE,
# 88              VINYL - INSTALL, , VACANT INSTALLATION
# 89                LVT - INSTALL, , VACANT INSTALLATION
# 90             CARPET - INSTALL, , VACANT INSTALLATION
# 91               REMOVE EXISTING FLOORS, , LVT TAKE UP
# 92              REMOVE EXISTING FLOORS, , TILE TAKE UP
# 93                                                 ALL
# 94                                 VANITY - FRONTS, ,
# 95                                     VANITY TOP , ,
# 96                                     VANITY TOP , ,
# 97                         SINK, PORCELAIN, UNDERMOUNT
# 98                          VANITY - BOX SETS, 72 IN,
# 99                          VANITY - BOX SETS, 60 IN,
# 100                         VANITY - BOX SETS, 48 IN,
# 101                   VANITY - BOX SETS, 36 IN, SHAKER
# 102                   VANITY - BOX SETS, 30 IN, SHAKER
# 103                                     SHOWER ROD, ,
# 104      LIGHT FIXTURE - BATH, BRUSHED NICKEL, 3-LIGHT
# 105                                         MIRROR, ,
# 106                                    SINK FAUCET, ,
# 107                            SINK FAUCET, , 1-HANDLE
# 108                                         TOLIET, ,
# 109                          WALL MOUNTED HARDWARE, ,
# 110          SHOWER TRIM, BRUSKED NICKEL, MASSAGE HEAD
# 111                              SHOWER TRIM, CHROME,
# 112                              SHOWER TRIM, CHROME,
# 113                                       BATH TUB, ,
# 114                                                ALL
# 115                          SHOWER PAN - REFINISH, ,
# 116  ADD ADDITIONAL BATHROOM, , INCLUDES ALL LABOR ...
# 117                                                ALL
# 118             VANITY - INSTALL FRONTS & HARDWARE, ,
# 119                           VANITY TOP - INSTALL, ,
# 120           VANITY - INSTALL BOX SETS & HARDWARE, ,
# 121                              FINISH ELECTRICAL, ,
# 122                                FINISH PLUMBING, ,
# 123  BATH/SHOWER SURROUND - INSTALL, , INCLUDES DEM...
# 124  BATH/SHOWER SURROUND - REFINISH, , SPECIALTY T...
# 125                              OTHER FINISH WORK, ,
# 126                                                ALL
# 127                                  PAINT - WALLS, ,
# 128                                          PAINT, ,
# 129                                  PAINT - WALLS, ,
# 130                                          PAINT, ,
# 131                                                ALL
# 132                                    CEILING FAN, ,
# 133  LIGHT FIXTURE - BED OR LIVING AREA, 16 IN, FLU...
# 134  LIGHT FIXTURE - BED OR LIVING AREA, 14 IN, FLU...
# 135  LIGHT FIXTURE - BED OR LIVING AREA, 5.26 IN, F...
# 136                        ELECTRICAL OUTLET - USB, ,
# 137                       ELECTRICAL OUTLET, , PACKAGE
# 138                        WALL PLATE, 1 GANG, PACKAGE
# 139                        WALL PLATE, 2 GANG, PACKAGE
# 140                                                ALL
# 141                  WINDOW TREATMENT, 2 IN, FAUX WOOD
# 142                                                ALL
# 143                                        DRYWALL, ,
# 144                               DOOR PREHUNG KIT, ,
# 145                            BASEBOARD - INSTALL, ,
# 146                                                ALL
# 147                                      SITE PREP, ,
# 148                                           DEMO, ,
# 149                                  WASTE HAULING, ,
# 150                                       CLEANING, ,
# 151                                                ALL
# 152                                 SUPERINTENDENT, ,
# 153                                       LABORERS, ,
# 154                                      LOST TIME, ,
# 155                                          OTHER, ,
# 156                                         TRAVEL, ,
# 157                             OPERATING EXPENSES, ,
# 158                                                ALL
# 159                         LICENSES AND INSURANCE, ,
# 160                                         PROFIT, ,
# 161                                    CONTINGENCY, ,
# 162                             TAILORBIRD RFP FEE, ,
# 163                                                ALL
#
#                             rfp_spec_tags rfp_notes                   owner  \
# 0         SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 1         SUB CATEGORY, MATERIAL, STYLE A       ANY  CATALYST HOUSING GROUP
# 2         SUB CATEGORY, MATERIAL, STYLE A       ANY  CATALYST HOUSING GROUP
# 3         SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 4         SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 5         SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 6         SUB CATEGORY, MATERIAL, QUALITY       ANY                     ANY
# 7         SUB CATEGORY, MATERIAL, QUALITY       ANY                     ANY
# 8         SUB CATEGORY, MATERIAL, QUALITY       ANY  CATALYST HOUSING GROUP
# 9         SUB CATEGORY, MATERIAL, QUALITY       ANY                     ANY
# 10        SUB CATEGORY, MATERIAL, QUALITY       ANY                     ANY
# 11           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 12        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 13        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 14        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 15        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 16           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 17           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 18           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 19           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 20           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 21           SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 22        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 23        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 24        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 25        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 26        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 27        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 28        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 29     SUB CATEGORY, COLOR, DEFINING SIZE       ANY                     ANY
# 30                                    ALL       ANY                     ANY
# 31          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 32          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 33          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 34          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 35          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 36          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 37          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 38          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 39                                    ALL       ANY                     ANY
# 40       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 41       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 42       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 43       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 44       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 45       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 46       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 47       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 48       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 49       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 50       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 51       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 52       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 53       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 54       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 55       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 56       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 57       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 58       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 59       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 60       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 61       SUB CATEGORY, MANUFACTURE, COLOR       ANY                     ANY
# 62                                    ALL       ANY                     ANY
# 63          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 64          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 65          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 66          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 67          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 68          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 69          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 70                                    ALL       ANY                     ANY
# 71   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 72   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 73   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 74   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 75   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 76   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 77   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 78   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 79   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 80   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 81   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 82   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 83   SUB CATEGORY, MANUFACTURE, BRANDLINE       ANY                     ANY
# 84                   SUB CATEGORY, FINISH       ANY                     ANY
# 85                   SUB CATEGORY, FINISH       ANY                     ANY
# 86                   SUB CATEGORY, FINISH       ANY                     ANY
# 87          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 88          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 89          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 90          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 91          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 92          SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 93                                    ALL       ANY                     ANY
# 94        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 95        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 96        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 97        SUB CATEGORY, MATERIAL, STYLE A       ANY                     ANY
# 98   SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 99   SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 100  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 101  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 102  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 103          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 104          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 105          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 106          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 107          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 108          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 109          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 110          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 111          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 112          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 113          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 114          SUB CATEGORY, COLOR, STYLE A       ANY                     ANY
# 115         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 116         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 117                                   ALL       ANY                     ANY
# 118         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 119         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 120         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 121         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 122         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 123         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 124         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 125         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 126                                   ALL       ANY                     ANY
# 127        SUB CATEGORY, MANUFACTURE, SKU       ANY                     ANY
# 128         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 129        SUB CATEGORY, MANUFACTURE, SKU       ANY                     ANY
# 130         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 131                                   ALL       ANY                     ANY
# 132  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 133  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 134  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 135  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 136  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 137  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 138  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 139  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 140                                   ALL       ANY                     ANY
# 141  SUB CATEGORY, DEFINING SIZE, STYLE A       ANY                     ANY
# 142                                   ALL       ANY                     ANY
# 143         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 144         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 145         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 146                                   ALL       ANY                     ANY
# 147         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 148         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 149         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 150         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 151                                   ALL       ANY                     ANY
# 152         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 153         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 154         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 155         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 156         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 157         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 158                                   ALL       ANY                     ANY
# 159         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 160         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 161         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 162         SUB CATEGORY, MATERIAL, NOTES       ANY                     ANY
# 163                                   ALL       ANY                     ANY
#
#     property_manager            geography            manufacture         sku_  \
# 0                ANY                  ANY                    ANY          ANY
# 1       GREYSTAR NCA  NORTHERN CALIFORNIA                    ANY          ANY
# 2       GREYSTAR NCA  NORTHERN CALIFORNIA                    ANY          ANY
# 3                ANY                  ANY                    ANY          ANY
# 4           AVENUE 5              ARIZONA                    ANY          ANY
# 5                ANY                  ANY                    ANY          ANY
# 6                ANY                  ANY                    ANY          ANY
# 7                ANY                  ANY                    ANY          ANY
# 8       GREYSTAR NCA  NORTHERN CALIFORNIA                    ANY          ANY
# 9                ANY                  ANY                    ANY          ANY
# 10               ANY                  ANY                    ANY          ANY
# 11               ANY                  ANY                    ANY          ANY
# 12               ANY                  ANY                    ANY          ANY
# 13               ANY                  ANY                    ANY          ANY
# 14               ANY                  ANY                 KOHLER          ANY
# 15               ANY                  ANY                 KOHLER          ANY
# 16               ANY                  ANY                    ANY          ANY
# 17               ANY                  ANY                    ANY          ANY
# 18               ANY                  ANY                 KOHLER          ANY
# 19               ANY                  ANY                 KOHLER          ANY
# 20               ANY                  ANY                 KOHLER          ANY
# 21               ANY                  ANY                    ANY          ANY
# 22               ANY                  ANY                    ANY          ANY
# 23               ANY                  ANY           PORCELANOSSA          ANY
# 24               ANY                  ANY           PORCELANOSSA          ANY
# 25               ANY                  ANY           PORCELANOSSA          ANY
# 26               ANY                  ANY           PORCELANOSSA          ANY
# 27               ANY                  ANY           PORCELANOSSA          ANY
# 28               ANY                  ANY                 MINCEY          ANY
# 29               ANY                  ANY  MAINTENANCE WAREHOUSE          ANY
# 30               ANY                  ANY                    ANY          ANY
# 31               ANY                  ANY                    ANY          ANY
# 32               ANY                  ANY                    ANY          ANY
# 33               ANY                  ANY                    ANY          ANY
# 34               ANY     LOW COST REGIONS                    ANY          ANY
# 35               ANY     MED COST REGIONS                    ANY          ANY
# 36               ANY                  ANY                    ANY          ANY
# 37               ANY                  ANY                    ANY          ANY
# 38               ANY                  ANY                    ANY          ANY
# 39               ANY                  ANY                    ANY          ANY
# 40               ANY                  ANY                    ANY          ANY
# 41               ANY                  ANY                  AMANA   ADB1400AGS
# 42               ANY                  ANY             FRIGIDAIRE   FFCD2413US
# 43               ANY                  ANY                SAMSUNG  DW80R9950US
# 44               ANY                  ANY                  AMANA   AMV2307PFS
# 45               ANY                  ANY             FRIGIDAIRE   FFMV1645TS
# 46               ANY                  ANY                SAMSUNG  MC17J8000CS
# 47               ANY                  ANY                  AMANA   ACR4303MFS
# 48               ANY                  ANY              WHIRLPOOL   WEE510S0FS
# 49               ANY                  ANY             FRIGIDAIRE   FFEF3016VS
# 50               ANY                  ANY                SAMSUNG  NE63T8111SS
# 51               ANY                  ANY                  AMANA   ART318FFDS
# 52               ANY                  ANY             FRIGIDAIRE  FFFHI1835VS
# 53               ANY                  ANY             FRIGIDAIRE   FFTR1814TS
# 54               ANY                  ANY                SAMSUNG  RF18HFENBSR
# 55               ANY                  ANY              WHIRLPOOL  WWRT112CZJB
# 56               ANY                  ANY              WHIRLPOOL  WWRT112CZJZ
# 57               ANY                  ANY                    ANY          ANY
# 58               ANY                  ANY             FRIGIDAIRE   FHWC3025MS
# 59               ANY                  ANY              WHIRLPOOL   UXT4030ADS
# 60               ANY                  ANY                SAMSUNG  DVE45R6300W
# 61               ANY                  ANY                SAMSUNG  WF45R6300AW
# 62               ANY                  ANY                    ANY          ANY
# 63               ANY                  ANY                    ANY          ANY
# 64               ANY                  ANY                    ANY          ANY
# 65               ANY                  ANY                    ANY          ANY
# 66               ANY                  ANY                    ANY          ANY
# 67               ANY                  ANY                    ANY          ANY
# 68               ANY                  ANY                    ANY          ANY
# 69               ANY                  ANY                    ANY          ANY
# 70               ANY                  ANY                    ANY          ANY
# 71               ANY                  ANY                   SHAW        VPS23
# 72               ANY                  ANY                 MOHAWK        BALP2
# 73               ANY                  ANY                    ANY          ANY
# 74               ANY                  ANY                 MOHAWK          ANY
# 75               ANY                  ANY                 MOHAWK        PM391
# 76               ANY                  ANY                 MOHAWK       PBP99A
# 77               ANY                  ANY                 MOHAWK        PM391
# ...
# 45                                                  MI
# 46                                                  MI
# 47                                                  MI
# 48                                                  MI
# 49                                                  MI
# 50                                                  MI
# 51                                                  MI
# 52                                     FERGUSON PRICES
# 53                                                  MI
# 54                                                  MI
# 55                                     FERGUSON PRICES
# 56                                     FERGUSON PRICES
# 57                                         GREYSTAR CO
# 58                                                  MI
# 59                                                  MI
# 60                                                  MI
# 61                                                  MI
# 62                                                  MI
# 63                                               AMANA
# 64                                                  MI
# 65                                               AMANA
# 66                                               AMANA
# 67                                               AMANA
# 68                                                  MI
# 69                                               AMANA
# 70                                                  MI
# 71                                                  MI
# 72                                                  MI
# 73                                                  MI
# 74                                                  MI
# 75                                                  MI
# 76                                                  MI
# 77                                                  MI
# 78                                                  MI
# 79                                                  MI
# 80                                                  MI
# 81                                         REDI CARPET
# 82                                         REDI CARPET
# 83                                                  MI
# 84                                                  MI
# 85                                                  MI
# 86                                                  MI
# 87                                                  MI
# 88                                                  MI
# 89                                                  MI
# 90                                                  MI
# 91                                                  MI
# 92                                                  MI
# 93                                                  MI
# 94                                                  MI
# 95                                                  MI
# 96                                                  MI
# 97                               INCLUDES INSTALLATION
# 98                                                  MI
# 99                                                  MI
# 100                                                 MI
# 101                                                 MI
# 102                                                 MI
# 103                            TIM MADE THIS NUMBER UP
# 104                            TIM MADE THIS NUMBER UP
# 105                            TIM MADE THIS NUMBER UP
# 106                            TIM MADE THIS NUMBER UP
# 107                                                 MI
# 108                            TIM MADE THIS NUMBER UP
# 109                                         HOME DEPOT
# 110                                                 MI
# 111                             INCLUDES $54 VALVE KIT
# 112                             INCLUDES $90 VALVE KIT
# 113                                                 MI
# 114                                       FROM LIONEL?
# 115                                                 MI
# 116                                                 MI
# 117                                                 MI
# 118                                                 MI
# 119                                                 MI
# 120                            TIM MADE THIS NUMBER UP
# 121                            TIM MADE THIS NUMBER UP
# 122                            TIM MADE THIS NUMBER UP
# 123                                       FROM LIONEL?
# 124                                                 MI
# 125                                                 MI
# 126                                                 MI
# 127                     PER AVE 5, PREVIOUSLY 1-1.5 SF
# 128                     PER AVE 5, PREVIOUSLY 1-1.5 SF
# 129                                                 MI
# 130                                                 MI
# 131                                                 MI
# 132                                                 MI
# 133                                                 MI
# 134                                                 MI
# 135                                                 MI
# 136                                                 MI
# 137                                                 MI
# 138                                                 MI
# 139                                                 MI
# 140                                                 MI
# 141                            TIM MADE THIS NUMBER UP
# 142                                                 MI
# 143                            TIM MADE THIS NUMBER UP
# 144                            TIM MADE THIS NUMBER UP
# 145                            TIM MADE THIS NUMBER UP
# 146                                                 MI
# 147                            TIM MADE THIS NUMBER UP
# 148                            TIM MADE THIS NUMBER UP
# 149                            TIM MADE THIS NUMBER UP
# 150                            TIM MADE THIS NUMBER UP
# 151                                                 MI
# 152                            TIM MADE THIS NUMBER UP
# 153                            TIM MADE THIS NUMBER UP
# 154                            TIM MADE THIS NUMBER UP
# 155                            TIM MADE THIS NUMBER UP
# 156                            TIM MADE THIS NUMBER UP
# 157                            TIM MADE THIS NUMBER UP
# 158                                                 MI
# 159                                                 MI
# 160                                                 MI
# 161                                                 MI
# 162                                                 MI
# 163                                                 MI
#
#                                         archive_name
# 0            H1 KITCHEN CABINETS WOOD SHAKER - LNIN
# 1      H2 KITCHEN CABINETS WOOD SHAKER - NEW FRONTS
# 2      H300 KITCHEN CABINETS FLAT FACE - NEW FRONTS
# 3                   H3 KITCHEN CABINETS WOOD SHAKER
# 4                         H4 KITCHEN PAINT CABINETS
# 5             H5 KITCHEN PAINT CABINETS- BOXES ONLY
# 6                 H6 KITCHEN COUNTER TOP GRANITE L1
# 7                     H7 KITCHEN COUNTER TOP QUARTZ
# 8               H133 KITCHEN COUNTER TOP QUARTZ 2CM
# 9                 H8 KITCHEN COUNTER TOP GRANITE L2
# 10                   H9 KITCHEN COUNTER TOP FORMICA
# 11                     H10 KITCHEN CABINET HARDWARE
# 12                          H11 KITCHEN SINK - APRO
# 13                            H12 KITCHEN SINK - HD
# 14               H13 KITCHEN SINK KOHLER 24" UNDERM
# 15               H14 KITCHEN SINK KOHLER 32" UNDERM
# 16                    H15 KITCHEN FAUCET - STANDARD
# 17         H16 KITCHEN FAUCET (DOWN FLEX) - SEASONS
# 18                H17 KITCHEN FAUCET KOHLER BASE CH
# 19                H18 KITCHEN FAUCET KOHLER BASE BL
# 20             H19 KITCHEN FAUCET KOHLER UPGRADE CH
# 21                        H20 KITCHEN LIGHT FIXTURE
# 22              H21 ACCENT TILE BACKSPLASH MATERIAL
# 23            H22 KITCHEN SUBWAY TILE  - MID CLASICO
# 24            H23 KITCHEN ACCENT TILE - HIGH CLASICO
# 25              H24 KITCHEN ACCENT TILE - LOW STUDIO
# 26              H25 KITCHEN ACCENT TILE - HIGH LAGOM
# 27                  H26 KITCHEN ACCENT TILE -  LAGOM
# 28       H27 KITCHEN ACCENT TILE CULTURED MARBLE ALL
# 29                    H132 KITCHEN GARBAGE DISPOSAL
# 30                                                MI
# 31                 H28 KITCHEN CABINET INSTALLATION
# 32             H29 KITCHEN COUNTER TOP INSTALLATION
# 33     H30 KITCHEN COUNTER TOP INSTALLATION FORMICA
# 34                  H201 KITCHEN BACKSPLASH INSTALL
# 35                  H30 KITCHEN LABOR- TILE INSTALL
# 36               H31 KITCHEN LABOR- FINISH PLUMBING
# 37             H32 KITCHEN LABOR- FINISH ELECTRICAL
# 38             H33 KITCHEN LABOR- GENERAL CARPENTRY
# 39                                                MI
# 40                       H35 APPLIANCES COOKTOP GAS
# 41                H36 APPLIANCES DISHWASHER - AMANA
# 42           H37 APPLIANCES DISHWASHER - FRIGIDAIRE
# 43              H38 APPLIANCES DISHWASHER - SAMSUNG
# 44                 H39 APPLIANCES MICROWAVE - AMANA
# 45            H40 APPLIANCES MICROWAVE - FRIGIDAIRE
# 46               H41 APPLIANCES MIRCOWAVE - SAMSUNG
# 47                    H42 APPLIANCES RANGE  - AMANA
# 48                H43 APPLIANCES RANGE  - WHIRLPOOL
# 49                H44 APPLIANCES RANGE - FRIGIDAIRE
# 50                   H45 APPLIANCES RANGE - SAMSUNG
# 51             H46 APPLIANCES REFRIDGERATOR - AMANA
# 52     H47 APPLIANCES REFRIDGERATOR - FRIGIDAIRE BL
# 53        H48 APPLIANCES REFRIDGERATOR - FRIGIDAIRE
# 54           H49 APPLIANCES REFRIDGERATOR - SAMSUNG
# 55                                                MI
# 56                                                MI
# 57   H52 APPLIANCES STACKED WASHER/DRYER - STANDARD
# 58                 H53 APPLIANCES VENT - FRIGIDAIRE
# 59                  H54 APPLIANCES VENT - WHIRLPOOL
# 60               H55 APPLIANCES W/D DRYER - SAMSUNG
# 61              H56 APPLIANCES W/D WASHER - SAMSUNG
# 62                                                MI
# 63                H57 APPLIANCES INSTALL DISHWASHER
# 64          H58 APPLIANCES (NEW) INSTALL DISHWASHER
# 65                    H59 APPLIANCES INSTALL FRIDGE
# 66                 H60 APPLIANCES INSTALL MICROWAVE
# 67                     H61 APPLIANCES INSTALL RANGE
# 68              H62 APPLIANCES INSTALL WASHER/DRYER
# 69                  H34 KITCHEN LABOR- INSTALL VENT
# 70                                                MI
# 71                          H57 FLOORING LVT - SHAW
# 72                        H58 FLOORING LVT - MOHAWK
# 73                         H59 FLOORING SHEET VINYL
# 74                              H59 FLOORING CARPET
# 75                  H60 FLOORING CARPET CLASICO- LOW
# 76                 H61 FLOORING CARPET CLASICO- HIGH
# 77                   H62 FLOORING CARPET STUDIO- LOW
# 78                  H63 FLOORING CARPET STUDIO- HIGH
# 79                    H64 FLOORING CARPET LAGOM- LOW
# 80                   H65 FLOORING CARPET LAGOM- HIGH
# 81                 H66 FLOORING SELF-LEVEL COMPOUND
# 82          H67 FLOORING NEW BASEBOARDS (MAT & LAB)
# 83       H68 FLOORING NEW QUARTER ROUND (MAT & LAB)
# 84      H69 FLOORING CLEAN AND RESEAL EXISTING TILE
# 85      H70 FLOORING BUFF AND REFINISH EXISTING HWF
# 86      H71 FLOORING SAND AND REFINISH EXISTING HWF
# 87                        H72 FLOORING KITCHEN TILE
# 88            H72 FLOORING SHEET VINYL INSTALLATION
# 89                    H73 FLOORING LVT INSTALLATION
# 90                 H74 FLOORING CARPET INSTALLATION
# 91                   H75 FLOORING DEMO EXISTING LTV
# 92                  H76 FLOORING DEMO EXISTING TILE
# 93                                                MI
# 94                          H202 BATH VANITY FRONTS
# 95                    H203 BATH VANITY TOP - QUARTZ
# 96                  H204 BATH VANITY TOP - LAMINATE
# 97                                    H77 BATH SINK
# 98                H130 BATH VANITY & SINK - 72 INCH
# 99                H131 BATH VANITY & SINK - 60 INCH
# 100                H78 BATH VANITY & SINK - 48 INCH
# 101                H79 BATH VANITY & SINK - 36 INCH
# 102                H80 BATH VANITY & SINK - 30 INCH
# 103                             H81 BATH SHOWER ROD
# 104                          H82 BATH LIGHT FIXTURE
# 105                                 H83 BATH MIRROR
# 106                                 H84 BATH FAUCET
# 107                                 H85 BATH FAUCET
# 108                                 H86 BATH TOILET
# 109                    H87 BATH ACCESSORIES PACKAGE
# 110                            H88 BATH SHOWER HEAD
# 111                     H89 SHOWER/TUB TRIM BASE CH
# 112                  H90 SHOWER/TUB TRIM UPGRADE CH
# 113                               H91 BATH TUB- NEW
# 114                  H92 BATH SHOWER PANELS AND PAN
# 115               H93 BATH SHOWER SURROUND REFINISH
# 116                                 H92 ADD 2ND BATH
# 117                                               MI
# 118                 H204 BATH VANITY FRONTS INSTALL
# 119                    H205 BATH VANITY TOP INSTALL
# 120     H93 BATH LABOR- VANITY, MIRROR, ROD INSTALL
# 121               H94 BATH LABOR- FINISH ELECTRICAL
# 122                 H95 BATH LABOR- FINISH PLUMBING
# 123           H96 BATH LABOR- SHOWER DEMO & INSTALL
# 124              H100 TILE - WALLS EPOXY SPRAY TILE
# 125               H97 BATH LABOR- GENERAL CARPENTRY
# 126                                               MI
# 127                        H98 PAINT PAINT MATERIAL
# 128                           H99 PAINT PAINT LABOR
# 129                        H98 PAINT PAINT MATERIAL
# 130                           H99 PAINT PAINT LABOR
# 131                                               MI
# 132                  H140 LIGHT FIXTURE CEILING FAN
# 133          H101 LIGHT FIXTURE LIVING AREAS - HIGH
# 134           H102 LIGHT FIXTURE LIVING AREAS - MID
# 135           H103 LIGHT FIXTURE LIVING AREAS - LOW
# 136                   H104 ELECTRICAL OUTLET W/ USB
# 137                 H105 ELECTRICAL OUTLET STANDARD
# 138                  H106 WALL PLATE 1-GANG (PCKGE)
# 139                  H107 WALL PLATE 2-GANG (PCKGE)
# 140                                               MI
# 141                         H107 WINDOWS MINIBLINDS
# 142                                               MI
# 143                  H109 REPAIRS DRYWALL MAT & LAB
# 144                     H110 REPAIRS DOORS MATERIAL
# 145                   H112 REPAIRS MOLDING MATERIAL
# 146                                               MI
# 147                    H114 GENERAL SITE PREP LABOR
# 148                         H115 GENERAL DEMO LABOR
# 149                        H116 GENERAL  WASTE HAUL
# 150                           H117 GENERAL CLEANING
# 151                                               MI
# 152                   H118 OVER HEAD SUPERINTENDENT
# 153                         H119 OVER HEAD LABORERS
# 154                        H120 OVER HEAD LOST TIME
# 155                            H121 OVER HEAD OTHER
# 156                           H122 OVER HEAD TRAVEL
# 157               H123 OVER HEAD OPERATING EXPENSES
# 158                                               MI
# 159                       2% LICENSES AND INSURANCE
# 160                                       9% PROFIT
# 161                                  3% CONTINGENCY
# 162                           1% TAILORBIRD RFP FEE
# 163                                     EXCLUDE - -

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://localhost/TB')

# %%
df_ext.to_sql('sku_data', con=engine, index=False, if_exists='replace')

# %% [markdown]
# ### Bulding the Spec Metadata

# %%
pd.read_json("../data/external/sample.json")
# Out:
#              category_name                                              items
# 0                  Kitchen  [{'name': 'Cabinets', 'options': ['None', 'New...
# 1               Appliances  [{'name': 'Refrigerator Style', 'options': ['N...
# 2                 Bathroom  [{'name': 'Cabinets', 'options': ['None', 'New...
# 3                 Flooring  [{'name': 'Bedroom', 'options': ['None', 'New ...
# 4  Paint & living fixtures  [{'name': 'Paint', 'options': ['None', 'Fresh ...
# 5         Repair & windows  [{'name': 'Replace windows ?', 'options': ['No...

# %%
import json

with open("../data/external/sample.json", encoding='utf-8') as f:
    data = json.load(f)

# %%
items = pd.json_normalize(data, record_path=['items'], meta=['category_name'])
items.head()
# Out:
#               name                                            options  \
# 0         Cabinets  [None, New Boxsets, New Doors/Drawers, Paint D...
# 1    Cabinet Style                                [Any, Shaker, Flat]
# 2         Material                               [Any, MDF, All Wood]
# 3           Finish               [Any, Painted, Thermofoil, Melamine]
# 4  Handle hardware                               [Any, Bars, Fingers]
#
#   category_name
# 0       Kitchen
# 1       Kitchen
# 2       Kitchen
# 3       Kitchen
# 4       Kitchen

# %%
items.shape
# Out:
# (77, 3)

# %% [markdown]
# ## Read the spec object and match it with the SKU table

# %%
import json
from bson import ObjectId
from bson import json_util

class JSONEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, ObjectId):
            return str(o)
        return json.JSONEncoder.default(self, o)

##JSONEncoder().encode(analytics)

# %%
#with open("../data/external/project_josh.json", encoding='utf-8') as f:
#    p_data = json.load(f)

# %%
##json.loads(json_util.dumps(p_txt))

# %%
with open("../data/external/pinecone.json") as f:
    p_data = json.loads(json_util.dumps(f.read()))

# %%
##p_data

# %%
##pd.read_json(p_data)

# %% [markdown]
# ## Develop code to load data into MongoDB

# %%
from pymongo import MongoClient
from pprint import pprint

# %%
client = MongoClient('mongodb://127.0.0.1:27017/')

# %%
db=client.admin
# Issue the serverStatus command and print the results
serverStatusResult=db.command("serverStatus")
##pprint(serverStatusResult)

# %%
db = client.tb
